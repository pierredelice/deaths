# %%
import os
import glob
import pandas as pd
from pandas import Series, DataFrame
from dataset import Dataset
from params import get_params

# %%
params = get_params()
dataset = Dataset(params)
df = dataset._get_data()

# %%
df.shape
# Out:
# (8933681, 28)

# %%
df
# Out:
#                                         nom_c  edad_c  edad causa_bas  \
# 0         DESCONOCIDO DESCONOCIDO DESCONOCIDO       0   888      R99X
# 1         DESCONOCIDO DESCONOCIDO DESCONOCIDO       0   888      X958
# 2         DESCONOCIDO DESCONOCIDO DESCONOCIDO       0   888      Y097
# 3                VAZQUEZ RODRIGUEZ ELDA MARIA       0   888      K830
# 4         DESCONOCIDO DESCONOCIDO DESCONOCIDO       0   888      K746
# ...                                       ...     ...   ...       ...
# 606162    DESCONOCIDO DESCONOCIDO DESCONOCIDO       9   999      Y349
# 606163    DESCONOCIDO DESCONOCIDO DESCONOCIDO       9   999      V099
# 606164  ALCARAZ NO ESPECIFICADO N.N. O CARLOS       9   999      W190
# 606165    SE IGNORA SE IGNORA NO IDENTIFICADO       9   999      Y349
# 606166                  ONTIVEROS COBOS JESUS       9   999      N391
#
#         nac_dia  base  nac_mes  nac_anio  sexo  afiliacion  ... def_mun  \
# ...

# %%
df.groupby('edo_civil')['base'].value_counts()
# Out:
# edo_civil  base
# 0          2021    35396
#            2017    15618
#            2020    15382
#            2022    13076
#            2016    12084
#                    ...
# 9          2013    15626
#            2014    14800
#            2022    13623
#            2011    12249
#            2010     9477
# Name: base, Length: 111, dtype: int64
